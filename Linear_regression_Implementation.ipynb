# %% [markdown]
# <a href="https://colab.research.google.com/github/mihitkeshav/Linear-Regression-Implmenatation/blob/master/Linear_regression_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-765d60ad-8695-453a-b70f-83b6d5ed26a8" name="files[]" multiple disabled />
#      <output id="result-765d60ad-8695-453a-b70f-83b6d5ed26a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving clusterincluster.txt to clusterincluster (2).txt
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('clusterincluster.txt', sep=" ", header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#          0        1  2
# 0  0.61532 -1.10720  0
# 1 -0.80069  0.59908  0
# 2 -0.70984  0.70436  0
# 3  0.59479  1.11830  0
# 4  0.41828 -0.90832  0

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
print(b1, b0)
# Out:
# -0.0005505415643391424 0.0016373603281164295

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y) #CClusteinCluster

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r2 = 1 - (r/t)
print(r2) #we can see very very less accuracy rate so this is not possible in linear regression
# Out:
# 3.03675230628464e-07

# %%
files.upload()
# Out:
#      <input type="file" id="files-46d77852-36a7-47e5-916e-40f2c5017ce7" name="files[]" multiple disabled />
#      <output id="result-46d77852-36a7-47e5-916e-40f2c5017ce7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Corners.txt to Corners (1).txt
# ...

# %%
df = pd.read_csv('Corners.txt', sep=" ", header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#          0       1  2
# 0   5.6059  2.6261  0
# 1   2.9514  3.2557  0
# 2   2.3487  3.9697  0
# 3   4.2354  2.0874  0
# 4  10.7730  3.9356  0

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
print(b1, b0)
# Out:
# 0.00494562512837592 0.10784692687503655

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y) #corners

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r2 = 1 - (r/t)
print(r2) #very very low accuracy
# Out:
# 2.6424858381224325e-05

# %%
files.upload()
# Out:
#      <input type="file" id="files-6cfaff08-fa84-4311-a705-45c07bebe1a0" name="files[]" multiple disabled />
#      <output id="result-6cfaff08-fa84-4311-a705-45c07bebe1a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DoubleMoon1.txt to DoubleMoon1.txt
# ...

# %%
df = pd.read_csv('DoubleMoon1.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#         0       1  2
# 0  5.7149  7.9558  0
# 1  4.8732  7.6269  0
# 2  7.6091  6.8000  0
# 3 -2.4985  7.4777  0
# 4 -3.3375  7.1567  0

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r2 = 1 - (r/t)
print(r2) #very  low accuracy
# Out:
# 0.2577773402536653

# %%
files.upload()
# Out:
#      <input type="file" id="files-d74f8e07-02d5-4ff7-af51-6db60bef22cf" name="files[]" multiple disabled />
#      <output id="result-d74f8e07-02d5-4ff7-af51-6db60bef22cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DoubleMoon2.txt to DoubleMoon2.txt
# ...

# %%
df = pd.read_csv('DoubleMoon2.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#          0        1  2
# 0 -0.54228  4.64840  0
# 1  5.15050  0.43904  0
# 2  2.27700  4.34060  0
# 3  3.60470  3.57480  0
# 4 -4.78410  1.88210  0

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r2 = 1 - (r/t)
print(r2) #very  low accuracy
# Out:
# 0.2889012795894267

# %%
files.upload()
# Out:
#      <input type="file" id="files-9aebf44b-3b1d-484a-a386-80405cc7a7af" name="files[]" multiple disabled />
#      <output id="result-9aebf44b-3b1d-484a-a386-80405cc7a7af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Half_kernel.txt to Half_kernel.txt
# ...

# %%
df = pd.read_csv('Half_kernel.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#           0        1  2
# 0 -10.42300 -11.8450  1
# 1  -2.18230  -3.5095  1
# 2  -2.11960   3.2810  1
# 3  -9.20980  11.6010  1
# 4   0.63919   2.1327  1

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r2 = 1 - (r/t)
print(r2) #very  low accuracy
# Out:
# 0.0017572914330266087

# %%
files.upload()
# Out:
#      <input type="file" id="files-d6b22895-45b4-4a4d-b43f-e32ca1afe42a" name="files[]" multiple disabled />
#      <output id="result-d6b22895-45b4-4a4d-b43f-e32ca1afe42a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Image1.txt to Image1.txt
# ...

# %%
df = pd.read_csv('Image1.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#         0       1  2
# 0 -3.0002 -3.0379  1
# 1 -2.5601 -4.0034  1
# 2 -3.0362 -3.4911  1
# 3 -3.6867 -1.7454  1
# 4 -2.8852 -3.3761  1

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r2 = 1 - (r/t)
print(r2) #good accuracy this can be done by linear regresssion
# Out:
# 0.8117180155905944

# %%
files.upload()
# Out:
#      <input type="file" id="files-f07d3840-ebd3-40bb-b59c-f66bb0a22e15" name="files[]" multiple disabled />
#      <output id="result-f07d3840-ebd3-40bb-b59c-f66bb0a22e15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Image2.txt to Image2.txt
# ...

# %%
df = pd.read_csv('Image2.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#         0       1  2
# 0 -2.4271 -2.0659  1
# 1 -3.2354 -4.1332  1
# 2 -1.8513 -4.6596  1
# 3 -2.1312 -2.3870  1
# 4 -2.1173 -3.5059  1

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r2 = 1 - (r/t)
print(r2) #accuracy better than other datasets
# Out:
# 0.7380585050674926

# %%
files.upload()
# Out:
#      <input type="file" id="files-9009cfbf-ae53-4010-9a96-4b2b58fb7a59" name="files[]" multiple disabled />
#      <output id="result-9009cfbf-ae53-4010-9a96-4b2b58fb7a59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Image3.txt to Image3.txt
# ...

# %%
df = pd.read_csv('Image3.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#         0        1  2
# 0  2.1668  5.48950  1
# 1 -1.9563 -0.79647  1
# 2  1.7243  1.35830  1
# 3  4.5019  6.03320  1
# 4  0.7053  4.16960  1

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r1 = 1 - (r/t)
print(r1) #very very low accuracy
# Out:
# 1.6205489172804732e-08

# %%
files.upload()
# Out:
#      <input type="file" id="files-8e129d4e-8ad1-4c09-9910-3681370ad72f" name="files[]" multiple disabled />
#      <output id="result-8e129d4e-8ad1-4c09-9910-3681370ad72f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Moon.txt to Moon.txt
# ...

# %%
df = pd.read_csv('Moon.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#         0        1  2
# 0 -2.9427  3.58780  0
# 1  1.1986  1.24730  0
# 2  1.4453  0.94387  0
# 3  2.5198  3.85000  0
# 4  3.3139 -2.53840  0

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r1 = 1 - (r/t)
print(r1) #very very low accuracy
# Out:
# 0.001040213170940163

# %%
files.upload()
# Out:
#      <input type="file" id="files-b6dbccfe-b048-463a-822d-89046be9b63f" name="files[]" multiple disabled />
#      <output id="result-b6dbccfe-b048-463a-822d-89046be9b63f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Outlier.txt to Outlier.txt
# ...

# %%
df = pd.read_csv('Outlier.txt',  header=None)
X = df.iloc[:,0]
Y =  df.iloc[:,1]
m = len(Y)
df.head()
# Out:
#         0        1  2
# 0 -15.077 -11.1390  0
# 1 -20.339   6.7695  0
# 2 -21.577  -7.7220  0
# 3 -26.673  -1.0707  0
# 4 -27.136 -14.5030  0

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

# %%
numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# %%
ax_x = np.max(X) + 100
min_x = np.min(X) - 100

# %%
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# %%
plt.plot(x, y)
plt.scatter(X, Y)

# %%
t = 0
r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    t += (Y[i] - mean_y) ** 2
    r += (Y[i] - y_pred) ** 2
r1 = 1 - (r/t)
print(r1) #very very low accuracy
# Out:
# 0.000628980025904613
