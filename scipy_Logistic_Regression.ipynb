# %% [markdown]
# <a href="https://colab.research.google.com/github/mihitkeshav/Linear-Regression-Implmenatation/blob/master/scipy_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-28156f35-09b3-4fb1-95eb-9acc5c13091f" name="files[]" multiple disabled />
#      <output id="result-28156f35-09b3-4fb1-95eb-9acc5c13091f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving clusterincluster.txt to clusterincluster (1).txt
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('clusterincluster.txt', sep=" ",header=None)
X = df.iloc[:,0:2]
y = df.iloc[:,2]
df.head()
# Out:
#          0        1  2
# 0  0.61532 -1.10720  0
# 1 -0.80069  0.59908  0
# 2 -0.70984  0.70436  0
# 3  0.59479  1.11830  0
# 4  0.41828 -0.90832  0

# %%
df.count()
# Out:
# 0    4996
# 1    4996
# 2    4996
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[354, 270],
#        [333, 292]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 51.72137710168134

# %%
files.upload()
# Out:
#      <input type="file" id="files-fe825c74-bcff-41cb-b756-138482a5766a" name="files[]" multiple disabled />
#      <output id="result-fe825c74-bcff-41cb-b756-138482a5766a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DoubleMoon2.txt to DoubleMoon2.txt
# ...

# %%
df = pd.read_csv('DoubleMoon2.txt',header=None)
X = df.iloc[:,0:2]
y = df.iloc[:,2]
df.head()
# Out:
#          0        1  2
# 0 -0.54228  4.64840  0
# 1  5.15050  0.43904  0
# 2  2.27700  4.34060  0
# 3  3.60470  3.57480  0
# 4 -4.78410  1.88210  0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[1263,    0],
#        [   0, 1237]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 100.0

# %%
files.upload()
# Out:
#      <input type="file" id="files-a285384b-619b-4094-af4d-7813bdfc03f9" name="files[]" multiple disabled />
#      <output id="result-a285384b-619b-4094-af4d-7813bdfc03f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Image3.txt to Image3.txt
# ...

# %%
df = pd.read_csv('Image3.txt',header=None)
X = df.iloc[:,0:2]
y = df.iloc[:,2]
df.head()
# Out:
#         0        1  2
# 0  2.1668  5.48950  1
# 1 -1.9563 -0.79647  1
# 2  1.7243  1.35830  1
# 3  4.5019  6.03320  1
# 4  0.7053  4.16960  1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[1262,    1],
#        [   1, 1236]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 99.92

# %%
files.upload()
# Out:
#      <input type="file" id="files-30b7c7c6-374a-4e87-936b-f9ec7983fb3c" name="files[]" multiple disabled />
#      <output id="result-30b7c7c6-374a-4e87-936b-f9ec7983fb3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Moon.txt to Moon.txt
# ...

# %%
df = pd.read_csv('Moon.txt',header=None)
X = df.iloc[:,0:2]
y = df.iloc[:,2]
df.head()
# Out:
#         0        1  2
# 0 -2.9427  3.58780  0
# 1  1.1986  1.24730  0
# 2  1.4453  0.94387  0
# 3  2.5198  3.85000  0
# 4  3.3139 -2.53840  0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[ 33,  16],
#        [ 16, 185]])

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy: 87.2
